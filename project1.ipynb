# %%
import numpy as np
import pandas as pd
import seaborn as sns
import datetime

# %%
# Source: http://web.mta.info/developers/turnstile.html


def get_data(week_nums):
    url = "http://web.mta.info/developers/data/nyct/turnstile/turnstile_{}.txt"
    dfs = []
    for week_num in week_nums:
        file_url = url.format(week_num)
        dfs.append(pd.read_csv(file_url))
    return pd.concat(dfs)
        
week_nums = [210925, 210918, 210911, 210904, 210828, 210821, 210814, 210807,210731,210724,210717,210710,210703]
turnstiles_df = get_data(week_nums)

# %%
turnstiles_df
# Out:
#           C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 0        A002  R051  02-00-00          59 ST  NQR456W      BMT  09/18/2021
# 1        A002  R051  02-00-00          59 ST  NQR456W      BMT  09/18/2021
# 2        A002  R051  02-00-00          59 ST  NQR456W      BMT  09/18/2021
# 3        A002  R051  02-00-00          59 ST  NQR456W      BMT  09/18/2021
# 4        A002  R051  02-00-00          59 ST  NQR456W      BMT  09/18/2021
# ...       ...   ...       ...            ...      ...      ...         ...
# 209825  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  07/02/2021
# 209826  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  07/02/2021
# 209827  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  07/02/2021
# 209828  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  07/02/2021
# 209829  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  07/02/2021
#
#             TIME     DESC  ENTRIES  \
# ...

# %%
turnstiles_df.to_csv("/Users/sarah/Desktop/data.csv",index=False)

# %%
import sqlalchemy
#create connection
engine = sqlalchemy.create_engine('postgresql://superset:superset@localhost:5432/superset')

# %%
turnstiles_df.to_sql("MTA3", con=engine, index=False)

# %%
# remove space from column name
turnstiles_df.rename(columns = {"EXITS                                                               ":"EXITS"}, inplace = True)

# %%
# Take the date and time fields into a single datetime column
turnstiles_df["DATE_TIME"] = pd.to_datetime(turnstiles_df.DATE + " " + turnstiles_df.TIME, 
                                            format="%m/%d/%Y %H:%M:%S")

# %%
turnstiles_df.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  09/18/2021  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  09/18/2021  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  09/18/2021  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  09/18/2021  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  09/18/2021  16:00:00
#
#       DESC  ENTRIES    EXITS           DATE_TIME
# 0  REGULAR  7637026  2613455 2021-09-18 00:00:00
# 1  REGULAR  7637036  2613457 2021-09-18 04:00:00
# 2  REGULAR  7637047  2613478 2021-09-18 08:00:00
# 3  REGULAR  7637104  2613524 2021-09-18 12:00:00
# 4  REGULAR  7637236  2613561 2021-09-18 16:00:00

# %%
# Take the date and time fields into a single datetime column
turnstiles_df['hour'] = turnstiles_df['DATE_TIME'].dt.hour

# %%
turnstiles_df.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  09/18/2021  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  09/18/2021  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  09/18/2021  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  09/18/2021  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  09/18/2021  16:00:00
#
#       DESC  ENTRIES    EXITS           DATE_TIME  hour
# 0  REGULAR  7637026  2613455 2021-09-18 00:00:00     0
# 1  REGULAR  7637036  2613457 2021-09-18 04:00:00     4
# 2  REGULAR  7637047  2613478 2021-09-18 08:00:00     8
# 3  REGULAR  7637104  2613524 2021-09-18 12:00:00    12
# 4  REGULAR  7637236  2613561 2021-09-18 16:00:00    16

# %%
#sample to data inserting for longitude

#update "MTA2" set long= '-76.5902226' where "STATION" = 'CLEVELAND ST';

# %%
#create new table

# create table mapny
# (
# 	lat double precision,
# 	long double precision,
# 	station text,
# 	entries integer
# );


# copy the sum of the data from old table to new one



#INSERT INTO  "mapny"
#select  lat , long , "STATION" ,sum("ENTRIES")
#from "MTA2" group by "STATION" , long , lat;
